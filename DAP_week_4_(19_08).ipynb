# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/Electric_Production.csv")
df['DATE'] = pd.to_datetime(df['DATE'])
df.rename(columns={'IPG2211A2N': 'Close'}, inplace=True)
df = df.sort_values(by='DATE')

plt.figure(figsize=(14, 7))
plt.plot(df['DATE'], df['Close'], label="Daily Closing Price",
         color="blue", linewidth=2)
plt.grid(True, linestyle="--", alpha=0.6)

events = {
    "2010-02-10": "New CEO Appointed",
    "2010-04-20": "Q1 Earnings",
    "2010-05-15": "Global Partnership",
    "2010-07-20": "Q2 Earnings",
    "2010-10-20": "Q3 Earnings",
    "2010-11-10": "Regulatory Fine"
}

for date, label in events.items():
    event_date = pd.to_datetime(date)
    price = df.loc[df['DATE'] == event_date, 'Close']
    if not price.empty:
        plt.scatter(event_date, price.values[0], color="red", s=80, zorder=5)
        plt.text(event_date, price.values[0] + 2, label, fontsize=9,
                 ha='left', va='bottom', rotation=20, color="darkred")

plt.title("XYZ Technologies – Stock Price Trend with Key Events (Yearly Analysis)",
          fontsize=16, weight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Closing Price (in USD)", fontsize=12)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("Electric_Production.csv")
df['DATE'] = pd.to_datetime(df['DATE'])
df.rename(columns={'IPG2211A2N': 'Close'}, inplace=True)
df = df.sort_values(by='DATE')

# Filter for one year (example: 2010 since events are given for 2010)
df_year = df[df['DATE'].dt.year == 2010]

# Define key events
events = {
    "2010-02-10": "New CEO Appointed",
    "2010-04-20": "Q1 Earnings",
    "2010-05-15": "Global Partnership",
    "2010-07-20": "Q2 Earnings",
    "2010-10-20": "Q3 Earnings",
    "2010-11-10": "Regulatory Fine"
}

# Create time series line chart
plt.figure(figsize=(14, 7))
plt.plot(df_year['DATE'], df_year['Close'], label="Daily Closing Price",
         color="blue", linewidth=2)

# Annotate key events with markers + text
for date, label in events.items():
    event_date = pd.to_datetime(date)
    price = df_year.loc[df_year['DATE'] == event_date, 'Close']
    if not price.empty:
        plt.scatter(event_date, price.values[0], color="red", s=100, zorder=5)
        plt.text(event_date, price.values[0] + 2, label, fontsize=9,
                 ha='center', color="darkred")

# Add title, labels, gridlines
plt.title("XYZ Technologies – Stock Price Trend with Key Events (Yearly Analysis)",
          fontsize=15, weight="bold")
plt.xlabel("Date", fontsize=12)
plt.ylabel("Closing Price (in USD)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
